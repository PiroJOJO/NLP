# %%
# !pip install spacy==3.6.1
# !pip install ml-datasets
# !python -m spacy download en_core_web_md
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# Collecting spacy==3.6.1
#   Downloading spacy-3.6.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 2.1 MB/s eta 0:00:0000:0100:010m
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: jinja2 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (3.0.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (2.22.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (3.0.8)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.2-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 KB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (20.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (0.3.2)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 KB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (1.7.4)
# Requirement already satisfied: numpy>=1.15.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (1.23.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (5.2.1)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.12-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (931 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 931.7/931.7 KB 3.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (2.4.5)
# Requirement already satisfied: setuptools in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (56.0.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (2.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (4.62.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy==3.6.1) (1.0.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/marie/newenv/lib/python3.8/site-packages (from packaging>=20.0->spacy==3.6.1) (2.4.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/marie/newenv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.6.1) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/marie/newenv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.6.1) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/marie/newenv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.6.1) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/marie/newenv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.6.1) (2020.12.5)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.3-py3-none-any.whl (34 kB)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/marie/newenv/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.8->spacy==3.6.1) (0.7.9)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/marie/newenv/lib/python3.8/site-packages (from typer<0.10.0,>=0.3.0->spacy==3.6.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/marie/newenv/lib/python3.8/site-packages (from jinja2->spacy==3.6.1) (2.1.3)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# Installing collected packages: spacy-loggers, spacy-legacy, langcodes, pathy, confection, thinc, spacy
#   Attempting uninstall: spacy-legacy
#     WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
#     Found existing installation: spacy-legacy 3.0.10
#     Uninstalling spacy-legacy-3.0.10:
#       Successfully uninstalled spacy-legacy-3.0.10
#   Attempting uninstall: pathy
#     WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
#     Found existing installation: pathy 0.6.2
#     Uninstalling pathy-0.6.2:
#       Successfully uninstalled pathy-0.6.2
#   Attempting uninstall: thinc
#     WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
#     Found existing installation: thinc 8.0.17
#     Uninstalling thinc-8.0.17:
#       Successfully uninstalled thinc-8.0.17
#   Attempting uninstall: spacy
#     WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
#     Found existing installation: spacy 3.0.0
#     Uninstalling spacy-3.0.0:
#       Successfully uninstalled spacy-3.0.0
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ru-core-news-sm 3.0.0 requires spacy<3.1.0,>=3.0.0, but you have spacy 3.6.1 which is incompatible.
# en-core-web-md 3.0.0 requires spacy<3.1.0,>=3.0.0, but you have spacy 3.6.1 which is incompatible.
# Successfully installed confection-0.1.3 langcodes-3.3.0 pathy-0.10.2 spacy-3.6.1 spacy-legacy-3.0.12 spacy-loggers-1.0.5 thinc-8.1.12
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/home/marie/newenv/bin/python3 -m pip install --upgrade pip' command.
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# Requirement already satisfied: ml-datasets in /home/marie/newenv/lib/python3.8/site-packages (0.2.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /home/marie/newenv/lib/python3.8/site-packages (from ml-datasets) (4.62.2)
# Requirement already satisfied: numpy>=1.7.0 in /home/marie/newenv/lib/python3.8/site-packages (from ml-datasets) (1.23.5)
# Requirement already satisfied: catalogue<3.0.0,>=0.2.0 in /home/marie/newenv/lib/python3.8/site-packages (from ml-datasets) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=1.0.1 in /home/marie/newenv/lib/python3.8/site-packages (from ml-datasets) (2.4.5)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/home/marie/newenv/bin/python3 -m pip install --upgrade pip' command.
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# Collecting en-core-web-md==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.6.0/en_core_web_md-3.6.0-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 4.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /home/marie/newenv/lib/python3.8/site-packages (from en-core-web-md==3.6.0) (3.6.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.1.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.7.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (5.2.1)
# Requirement already satisfied: numpy>=1.15.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.23.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.8)
# Requirement already satisfied: jinja2 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.62.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.12)
# Requirement already satisfied: pathy>=0.10.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.10.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.4.5)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.3.2)
# Requirement already satisfied: packaging>=20.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (20.9)
# Requirement already satisfied: setuptools in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (56.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/marie/newenv/lib/python3.8/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.22.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/marie/newenv/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.4.7)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/marie/newenv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/marie/newenv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/marie/newenv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/marie/newenv/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.25.11)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/marie/newenv/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/marie/newenv/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.1.3)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /home/marie/newenv/lib/python3.8/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/marie/newenv/lib/python3.8/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.1.3)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# Installing collected packages: en-core-web-md
#   Attempting uninstall: en-core-web-md
#     WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
#     Found existing installation: en-core-web-md 3.0.0
#     Uninstalling en-core-web-md-3.0.0:
#       Successfully uninstalled en-core-web-md-3.0.0
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# Successfully installed en-core-web-md-3.6.0
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/home/marie/newenv/lib/python3.8/site-packages)
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/home/marie/newenv/bin/python -m pip install --upgrade pip' command.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import spacy
from tqdm.auto import tqdm
from spacy.tokens import DocBin
from ml_datasets import imdb
train_data, valid_data = imdb()
nlp = spacy.load("en_core_web_md")

# %%
valid_data[0]
# Out:
# ("This film was reeeeeeallyyyy bad! Was it meant to be a comedy as I couldn't help laughing the whole way through it? what a waste of two hours! Donald Sutherland was wooden not that he was alone, everyone else was just as bad...and how miscast was linda hamilton???",
#  'neg')

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
nlp.pipe(train_data[0], as_tuples=True)
# Out:
# <generator object Language.pipe at 0x7f297c592f90>

# %%
def make_docs(data):
    """
    this will take a list of texts and labels
    and transform them in spacy documents
    data: list(tuple(text, label))
    returns: List(spacy.Doc.doc)
    """
    docs = []
    # nlp.pipe([texts]) is way faster than running
    # nlp(text) for each text
    # as_tuples allows us to pass in a tuple,
    # the first one is treated as text
    # the second one will get returned as it is.
#     a = tqdm(nlp.pipe(data, as_tuples=True), total = len(data))
    for doc, label in tqdm(nlp.pipe(data, as_tuples=True), total = len(data)):
        if label == 'neg':
            doc.cats["positive"] = 0
            doc.cats["negative"] = 1
        else:
            doc.cats["positive"] = 1
            doc.cats["negative"] = 0
        docs.append(doc)
    return docs

# %%
# это для примера, можно взять больше количество текстов
num_texts = 100
train_docs = make_docs(train_data[:num_texts])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# then we save it in a binary file to disc
doc_bin = DocBin(docs=train_docs)
doc_bin.to_disk("train.spacy")
# repeat for validation data
valid_docs = make_docs(valid_data[:num_texts])
doc_bin = DocBin(docs=valid_docs)
doc_bin.to_disk("valid.spacy")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# на этом месте мы идем в https://spacy.io/usage/training#quickstart, там настраиваем под себя конфиг в разделе quickstart, копируем его руками(!) в base_config.cfg, указываем правильные пути до трейн и вэлид
# но после этого некоторые поля возможно придется руками дописать, главное проверить что есть вот такие строчки:
#
# [nlp] <br>
# lang = "en" <br>
# pipeline = ["textcat"] <br>
# batch_size = 1000 <br>
#
# [components] <br>
#
# [components.textcat] <br>
# factory = "textcat" <br>
#
# или можно просто взять мой приложенный, он рабочий

# %%
# что здесь происходит: мы заполнили base_config, а эта команда на его основе прописывает config.cfg
! python -m spacy init fill-config base_config_361.cfg config_361.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# config_361.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config_361.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
! python -m spacy train config_361.cfg --output ./output # тренькаем модель
# Out:
# ℹ Saving to output directory: output
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['textcat']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TEXTCAT  CATS_SCORE  SCORE
# ---  ------  ------------  ----------  ------
#   0       0          0.25       33.33    0.33
#   2     200         34.82       72.92    0.73
#   4     400          0.55       74.42    0.74
#   6     600          0.11       70.83    0.71
#   8     800          0.06       73.13    0.73
#  10    1000          0.04       71.99    0.72
#  12    1200          0.03       71.99    0.72
#  14    1400          0.02       71.99    0.72
#  16    1600          0.01       71.99    0.72
#  18    1800          0.01       71.99    0.72
#  20    2000          0.01       70.83    0.71
# ✔ Saved pipeline to output directory
# output/model-last

# %%
# load thebest model from training
nlp = spacy.load("output/model-best")
text = ""
print("type : ‘quit’ to exit")
# predict the sentiment until someone writes quit
while text != "quit":
    text = input("Please enter example input: ")
    doc = nlp(text)
    print(doc.cats)
    if doc.cats['positive'] >.5:
        print(f"the sentiment is positive")
    else:
        print(f"the sentiment is negative")
# Out:
# type : ‘quit’ to exit
# Please enter example input: nice
# {'positive': 0.5137437582015991, 'negative': 0.4862562417984009}
# the sentiment is positive
# Please enter example input: bad review
# {'positive': 0.43967217206954956, 'negative': 0.5603277683258057}
# the sentiment is negative
# Please enter example input: bad
# {'positive': 0.460705429315567, 'negative': 0.5392945408821106}
# the sentiment is negative
# Please enter example input: quit
# {'positive': 0.513037919998169, 'negative': 0.48696205019950867}
# the sentiment is positive

# %%
# Out:
# {'positive': 0.02542225271463394, 'negative': 0.974577784538269}

# %%
nlp = spacy.load("output/model-best")

# %%
nlp('good review').cats
# Out:
# {'positive': 0.5100855231285095, 'negative': 0.4899144768714905}
